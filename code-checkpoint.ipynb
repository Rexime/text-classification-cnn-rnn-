# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple tensorflow==1.13.1
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple keras==2.2.4
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple tqdm
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple gensim
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple jieba

# %% [markdown]
# # 读取数据集

# %%
import pandas as pd
df=pd.read_csv("train.csv")
df_val=pd.read_csv("dev.csv")

# %%
df
# Out:
#         Class Index                                              Title  \
# 0                 3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1                 3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2                 3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3                 3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4                 3  Oil prices soar to all-time record, posing new...
# 5                 3        Stocks End Up, But Near Year Lows (Reuters)
# 6                 3               Money Funds Fell in Latest Week (AP)
# 7                 3  Fed minutes show dissent over inflation (USATO...
# 8                 3                            Safety Net (Forbes.com)
# 9                 3            Wall St. Bears Claw Back Into the Black
# 10                3              Oil and Economy Cloud Stocks' Outlook
# 11                3             No Need for OPEC to Pump More-Iran Gov
# 12                3          Non-OPEC Nations Should Up Output-Purnomo
# 13                3              Google IPO Auction Off to Rocky Start
# 14                3           Dollar Falls Broadly on Record Trade Gap
# 15                3                              Rescuing an Old Saver
# 16                3                       Kids Rule for Back-to-School
# 17                3          In a Down Market, Head Toward Value Funds
# 18                3                    US trade deficit swells in June
# 19                3                  Shell 'could be target for Total'
# 20                3                   Google IPO faces Playboy slip-up
# 21                3                     Eurozone economy keeps growing
# 22                3                           Expansion slows in Japan
# 23                3                    Rand falls on shock SA rate cut
# 24                3                   Car prices down across the board
# 25                3                  South Korea lowers interest rates
# 26                3                    Google auction begins on Friday
# 27                3                    HP shares tumble on profit news
# 28                3                   Mauritian textile firm cuts jobs
# 29                3                    Chad seeks refugee aid from IMF
# ...             ...                                                ...
# 108234            3          Wal-Mart Launches Rare Newspaper Ad Blitz
# 108235            3                    Christopher   Banks Disappoints
# 108236            3                         Gaining an Investment Edge
# 108237            4                       Iomega rolls out low-end NAS
# 108238            4                Mobile phones: An ear full of worms
# 108239            4  Update: Four Infineon executives jailed for DR...
# 108240            4  HP drops plans to put Compaq technology into H...
# 108241            4              Report: IBM's PC business up for sale
# 108242            4                Report: IBM Selling Its PC Business
# 108243            4                      ESPN Eyes Mobile Phone Market
# 108244            4                     Search Engine Forums Spotlight
# 108245            4       News: Phishing losses overestimated - survey
# 108246            4            News: Lycos antispam site taken offline
# 108247            3  IBM Hires Merrill Lynch to Find Buyer for PC U...
# 108248            4                 Napster Creator Stands Atop Snocap
# 108249            4                          Berners-Lee returns to UK
# 108250            1  Germany Says Thwarts Attack on Iraq PM, 3 Arre...
# 108251            2         New Jersey Supreme Court Cancels Bear Hunt
# 108252            1         High Court to Hear ISP, Cable Dispute (AP)
# 108253            1      Germany Stops Assassination Attempt on Allawi
# 108254            1                   Summit hopes for mine-free world
# 108255            1  Israel's Peres Urges Likud Hardliners to Back ...
# 108256            1  Hamas Hints It Is Open to Deal on Truce, State...
# 108257            3  Weak employment report points to still-sluggis...
# 108258            3               Halliburton Says Settlement on Track
# 108259            3  Retailers Seek To Block US Curbs on Chinese Te...
# 108260            4          Microsoft Sues Spammers over Porn E-Mails
# 108261            4           Spammers get taste of their own medicine
# 108262            4                   Jail terms for DRam price fixers
# 108263            4                Mobile phones: An ear full of worms
#
#                                               Description
# 0       Reuters - Short-sellers, Wall Street's dwindli...
# 1       Reuters - Private investment firm Carlyle Grou...
# 2       Reuters - Soaring crude prices plus worries\ab...
# 3       Reuters - Authorities have halted oil export\f...
# 4       AFP - Tearaway world oil prices, toppling reco...
# 5       Reuters - Stocks ended slightly higher on Frid...
# 6       AP - Assets of the nation's retail money marke...
# 7       USATODAY.com - Retail sales bounced back a bit...
# 8       Forbes.com - After earning a PH.D. in Sociolog...
# 9        NEW YORK (Reuters) - Short-sellers, Wall Stre...
# 10       NEW YORK (Reuters) - Soaring crude prices plu...
# 11       TEHRAN (Reuters) - OPEC can do nothing to dou...
# 12       JAKARTA (Reuters) - Non-OPEC oil exporters sh...
# 13       WASHINGTON/NEW YORK (Reuters) - The auction f...
# 14       NEW YORK (Reuters) - The dollar tumbled broad...
# 15      If you think you may need to help your elderly...
# 16      The purchasing power of kids is a big part of ...
# 17      There is little cause for celebration in the s...
# 18      The US trade deficit has exploded 19 to a reco...
# 19      Oil giant Shell could be bracing itself for a ...
# 20      The bidding gets underway for Google's public ...
# 21      Official figures show the 12-nation eurozone e...
# 22      Economic growth in Japan slows down as the cou...
# 23      Interest rates are trimmed to 7.5 by the South...
# 24      The cost of buying both new and second hand ca...
# 25      South Korea's central bank cuts interest rates...
# 26      An auction of shares in Google, the web search...
# 27      Hewlett-Packard shares fall after disappointin...
# 28      One of the oldest textile operators on the Ind...
# 29      Chad asks the IMF for a loan to pay for lookin...
# ...                                                   ...
# 108234   NEW YORK (Reuters) - Wal-Mart Stores Inc. &lt...
# 108235  The women's apparel retailer surprised investo...
# 108236  Whitney Tilson demonstrates how to beef up you...
# 108237  Iomega on Friday introduced a new network-atta...
# 108238  They're coming to mobile phones -- those nasty...
# 108239  Four executives at German memory vendor Infine...
# 108240  Hewlett-Packard(HP) has abandoned plans to int...
# 108241  IBM has put its PC business up for sale, accor...
# 108242  China's largest maker of PCs is one of the pot...
# 108243  Sports media company teams with Sprint to offe...
# 108244  Links to this week's topics from search engine...
# 108245  Fraud losses from email phishing attacks will ...
# 108246  Lycos Europe appears to have taken down its co...
# 108247  International Business Machines Corp., seeking...
# 108248  Napster creator Shawn Fanning is back with a n...
# 108249  p2pnet.net News - Sir Tim Berners-Lee, the man...
# 108250  Reuters - German police arrested three Iraqis ...
# 108251  TRENTON, NJ -- New Jersey #39;s top court shot...
# 108252  AP - The Supreme Court said Friday it would co...
# 108253  Three Iraqi citizens with alleged terrorist ti...
# 108254  It is in the nature of international conferenc...
# 108255   JERUSALEM (Reuters) - Labour Party chief Shim...
# 108256   RAMALLAH, West Bank (Reuters) - A Hamas leade...
# 108257  AFP - A weaker-than-anticipated report on the ...
# 108258  Petroleum and energy services giant Halliburto...
# 108259  The New York-based Association of Importers of...
# 108260  Laws require that sexually oriented solicitati...
# 108261  Internet users are being given the chance to h...
# 108262  Four executives at German memory supplier Infi...
# 108263  They #39;re coming to mobile phones - those na...
#
# [108264 rows x 3 columns]

# %%
df["content"]=df["Title"]+" "+df["Description"]
df_val["content"]=df_val["Title"]+" "+df_val["Description"]

# %%
df_val_num=df_val.shape[0]

# %%
df
# Out:
#         Class Index                                              Title  \
# 0                 3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1                 3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2                 3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3                 3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4                 3  Oil prices soar to all-time record, posing new...
# 5                 3        Stocks End Up, But Near Year Lows (Reuters)
# 6                 3               Money Funds Fell in Latest Week (AP)
# 7                 3  Fed minutes show dissent over inflation (USATO...
# 8                 3                            Safety Net (Forbes.com)
# 9                 3            Wall St. Bears Claw Back Into the Black
# 10                3              Oil and Economy Cloud Stocks' Outlook
# 11                3             No Need for OPEC to Pump More-Iran Gov
# 12                3          Non-OPEC Nations Should Up Output-Purnomo
# 13                3              Google IPO Auction Off to Rocky Start
# 14                3           Dollar Falls Broadly on Record Trade Gap
# 15                3                              Rescuing an Old Saver
# 16                3                       Kids Rule for Back-to-School
# 17                3          In a Down Market, Head Toward Value Funds
# 18                3                    US trade deficit swells in June
# 19                3                  Shell 'could be target for Total'
# 20                3                   Google IPO faces Playboy slip-up
# 21                3                     Eurozone economy keeps growing
# 22                3                           Expansion slows in Japan
# 23                3                    Rand falls on shock SA rate cut
# 24                3                   Car prices down across the board
# 25                3                  South Korea lowers interest rates
# 26                3                    Google auction begins on Friday
# 27                3                    HP shares tumble on profit news
# 28                3                   Mauritian textile firm cuts jobs
# 29                3                    Chad seeks refugee aid from IMF
# ...             ...                                                ...
# 108234            3          Wal-Mart Launches Rare Newspaper Ad Blitz
# 108235            3                    Christopher   Banks Disappoints
# 108236            3                         Gaining an Investment Edge
# 108237            4                       Iomega rolls out low-end NAS
# 108238            4                Mobile phones: An ear full of worms
# 108239            4  Update: Four Infineon executives jailed for DR...
# 108240            4  HP drops plans to put Compaq technology into H...
# 108241            4              Report: IBM's PC business up for sale
# 108242            4                Report: IBM Selling Its PC Business
# 108243            4                      ESPN Eyes Mobile Phone Market
# 108244            4                     Search Engine Forums Spotlight
# 108245            4       News: Phishing losses overestimated - survey
# 108246            4            News: Lycos antispam site taken offline
# 108247            3  IBM Hires Merrill Lynch to Find Buyer for PC U...
# 108248            4                 Napster Creator Stands Atop Snocap
# 108249            4                          Berners-Lee returns to UK
# 108250            1  Germany Says Thwarts Attack on Iraq PM, 3 Arre...
# 108251            2         New Jersey Supreme Court Cancels Bear Hunt
# 108252            1         High Court to Hear ISP, Cable Dispute (AP)
# 108253            1      Germany Stops Assassination Attempt on Allawi
# 108254            1                   Summit hopes for mine-free world
# 108255            1  Israel's Peres Urges Likud Hardliners to Back ...
# 108256            1  Hamas Hints It Is Open to Deal on Truce, State...
# 108257            3  Weak employment report points to still-sluggis...
# 108258            3               Halliburton Says Settlement on Track
# 108259            3  Retailers Seek To Block US Curbs on Chinese Te...
# 108260            4          Microsoft Sues Spammers over Porn E-Mails
# 108261            4           Spammers get taste of their own medicine
# 108262            4                   Jail terms for DRam price fixers
# 108263            4                Mobile phones: An ear full of worms
#
#                                               Description  \
# 0       Reuters - Short-sellers, Wall Street's dwindli...
# 1       Reuters - Private investment firm Carlyle Grou...
# 2       Reuters - Soaring crude prices plus worries\ab...
# 3       Reuters - Authorities have halted oil export\f...
# 4       AFP - Tearaway world oil prices, toppling reco...
# 5       Reuters - Stocks ended slightly higher on Frid...
# 6       AP - Assets of the nation's retail money marke...
# 7       USATODAY.com - Retail sales bounced back a bit...
# 8       Forbes.com - After earning a PH.D. in Sociolog...
# 9        NEW YORK (Reuters) - Short-sellers, Wall Stre...
# 10       NEW YORK (Reuters) - Soaring crude prices plu...
# 11       TEHRAN (Reuters) - OPEC can do nothing to dou...
# 12       JAKARTA (Reuters) - Non-OPEC oil exporters sh...
# 13       WASHINGTON/NEW YORK (Reuters) - The auction f...
# 14       NEW YORK (Reuters) - The dollar tumbled broad...
# 15      If you think you may need to help your elderly...
# 16      The purchasing power of kids is a big part of ...
# 17      There is little cause for celebration in the s...
# 18      The US trade deficit has exploded 19 to a reco...
# 19      Oil giant Shell could be bracing itself for a ...
# 20      The bidding gets underway for Google's public ...
# 21      Official figures show the 12-nation eurozone e...
# 22      Economic growth in Japan slows down as the cou...
# 23      Interest rates are trimmed to 7.5 by the South...
# 24      The cost of buying both new and second hand ca...
# 25      South Korea's central bank cuts interest rates...
# 26      An auction of shares in Google, the web search...
# 27      Hewlett-Packard shares fall after disappointin...
# 28      One of the oldest textile operators on the Ind...
# 29      Chad asks the IMF for a loan to pay for lookin...
# ...                                                   ...
# 108234   NEW YORK (Reuters) - Wal-Mart Stores Inc. &lt...
# 108235  The women's apparel retailer surprised investo...
# 108236  Whitney Tilson demonstrates how to beef up you...
# 108237  Iomega on Friday introduced a new network-atta...
# 108238  They're coming to mobile phones -- those nasty...
# 108239  Four executives at German memory vendor Infine...
# 108240  Hewlett-Packard(HP) has abandoned plans to int...
# 108241  IBM has put its PC business up for sale, accor...
# 108242  China's largest maker of PCs is one of the pot...
# 108243  Sports media company teams with Sprint to offe...
# 108244  Links to this week's topics from search engine...
# 108245  Fraud losses from email phishing attacks will ...
# 108246  Lycos Europe appears to have taken down its co...
# 108247  International Business Machines Corp., seeking...
# 108248  Napster creator Shawn Fanning is back with a n...
# 108249  p2pnet.net News - Sir Tim Berners-Lee, the man...
# 108250  Reuters - German police arrested three Iraqis ...
# 108251  TRENTON, NJ -- New Jersey #39;s top court shot...
# 108252  AP - The Supreme Court said Friday it would co...
# 108253  Three Iraqi citizens with alleged terrorist ti...
# 108254  It is in the nature of international conferenc...
# 108255   JERUSALEM (Reuters) - Labour Party chief Shim...
# 108256   RAMALLAH, West Bank (Reuters) - A Hamas leade...
# 108257  AFP - A weaker-than-anticipated report on the ...
# 108258  Petroleum and energy services giant Halliburto...
# 108259  The New York-based Association of Importers of...
# 108260  Laws require that sexually oriented solicitati...
# 108261  Internet users are being given the chance to h...
# 108262  Four executives at German memory supplier Infi...
# 108263  They #39;re coming to mobile phones - those na...
#
#                                                   content
# 0       Wall St. Bears Claw Back Into the Black (Reute...
# 1       Carlyle Looks Toward Commercial Aerospace (Reu...
# 2       Oil and Economy Cloud Stocks' Outlook (Reuters...
# 3       Iraq Halts Oil Exports from Main Southern Pipe...
# 4       Oil prices soar to all-time record, posing new...
# 5       Stocks End Up, But Near Year Lows (Reuters) Re...
# 6       Money Funds Fell in Latest Week (AP) AP - Asse...
# 7       Fed minutes show dissent over inflation (USATO...
# 8       Safety Net (Forbes.com) Forbes.com - After ear...
# 9       Wall St. Bears Claw Back Into the Black  NEW Y...
# 10      Oil and Economy Cloud Stocks' Outlook  NEW YOR...
# 11      No Need for OPEC to Pump More-Iran Gov  TEHRAN...
# 12      Non-OPEC Nations Should Up Output-Purnomo  JAK...
# 13      Google IPO Auction Off to Rocky Start  WASHING...
# 14      Dollar Falls Broadly on Record Trade Gap  NEW ...
# 15      Rescuing an Old Saver If you think you may nee...
# 16      Kids Rule for Back-to-School The purchasing po...
# 17      In a Down Market, Head Toward Value Funds Ther...
# 18      US trade deficit swells in June The US trade d...
# 19      Shell 'could be target for Total' Oil giant Sh...
# 20      Google IPO faces Playboy slip-up The bidding g...
# 21      Eurozone economy keeps growing Official figure...
# 22      Expansion slows in Japan Economic growth in Ja...
# 23      Rand falls on shock SA rate cut Interest rates...
# 24      Car prices down across the board The cost of b...
# 25      South Korea lowers interest rates South Korea'...
# 26      Google auction begins on Friday An auction of ...
# 27      HP shares tumble on profit news Hewlett-Packar...
# 28      Mauritian textile firm cuts jobs One of the ol...
# 29      Chad seeks refugee aid from IMF Chad asks the ...
# ...                                                   ...
# 108234  Wal-Mart Launches Rare Newspaper Ad Blitz  NEW...
# 108235  Christopher   Banks Disappoints The women's ap...
# 108236  Gaining an Investment Edge Whitney Tilson demo...
# 108237  Iomega rolls out low-end NAS Iomega on Friday ...
# 108238  Mobile phones: An ear full of worms They're co...
# 108239  Update: Four Infineon executives jailed for DR...
# 108240  HP drops plans to put Compaq technology into H...
# 108241  Report: IBM's PC business up for sale IBM has ...
# 108242  Report: IBM Selling Its PC Business China's la...
# 108243  ESPN Eyes Mobile Phone Market Sports media com...
# 108244  Search Engine Forums Spotlight Links to this w...
# 108245  News: Phishing losses overestimated - survey F...
# 108246  News: Lycos antispam site taken offline Lycos ...
# 108247  IBM Hires Merrill Lynch to Find Buyer for PC U...
# 108248  Napster Creator Stands Atop Snocap Napster cre...
# 108249  Berners-Lee returns to UK p2pnet.net News - Si...
# 108250  Germany Says Thwarts Attack on Iraq PM, 3 Arre...
# 108251  New Jersey Supreme Court Cancels Bear Hunt TRE...
# 108252  High Court to Hear ISP, Cable Dispute (AP) AP ...
# 108253  Germany Stops Assassination Attempt on Allawi ...
# 108254  Summit hopes for mine-free world It is in the ...
# 108255  Israel's Peres Urges Likud Hardliners to Back ...
# 108256  Hamas Hints It Is Open to Deal on Truce, State...
# 108257  Weak employment report points to still-sluggis...
# 108258  Halliburton Says Settlement on Track Petroleum...
# 108259  Retailers Seek To Block US Curbs on Chinese Te...
# 108260  Microsoft Sues Spammers over Porn E-Mails Laws...
# 108261  Spammers get taste of their own medicine Inter...
# 108262  Jail terms for DRam price fixers Four executiv...
# 108263  Mobile phones: An ear full of worms They #39;r...
#
# [108264 rows x 4 columns]

# %%
df=pd.concat([df,df_val],axis=0)
df=df[["Class Index","content"]]
df["category"]=df["Class Index"]

# %%
df
# Out:
#        Class Index                                            content  \
# 0                3  Wall St. Bears Claw Back Into the Black (Reute...
# 1                3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2                3  Oil and Economy Cloud Stocks' Outlook (Reuters...
# 3                3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4                3  Oil prices soar to all-time record, posing new...
# 5                3  Stocks End Up, But Near Year Lows (Reuters) Re...
# 6                3  Money Funds Fell in Latest Week (AP) AP - Asse...
# 7                3  Fed minutes show dissent over inflation (USATO...
# 8                3  Safety Net (Forbes.com) Forbes.com - After ear...
# 9                3  Wall St. Bears Claw Back Into the Black  NEW Y...
# 10               3  Oil and Economy Cloud Stocks' Outlook  NEW YOR...
# 11               3  No Need for OPEC to Pump More-Iran Gov  TEHRAN...
# 12               3  Non-OPEC Nations Should Up Output-Purnomo  JAK...
# 13               3  Google IPO Auction Off to Rocky Start  WASHING...
# 14               3  Dollar Falls Broadly on Record Trade Gap  NEW ...
# 15               3  Rescuing an Old Saver If you think you may nee...
# 16               3  Kids Rule for Back-to-School The purchasing po...
# 17               3  In a Down Market, Head Toward Value Funds Ther...
# 18               3  US trade deficit swells in June The US trade d...
# 19               3  Shell 'could be target for Total' Oil giant Sh...
# 20               3  Google IPO faces Playboy slip-up The bidding g...
# 21               3  Eurozone economy keeps growing Official figure...
# 22               3  Expansion slows in Japan Economic growth in Ja...
# 23               3  Rand falls on shock SA rate cut Interest rates...
# 24               3  Car prices down across the board The cost of b...
# 25               3  South Korea lowers interest rates South Korea'...
# 26               3  Google auction begins on Friday An auction of ...
# 27               3  HP shares tumble on profit news Hewlett-Packar...
# 28               3  Mauritian textile firm cuts jobs One of the ol...
# 29               3  Chad seeks refugee aid from IMF Chad asks the ...
# ...            ...                                                ...
# 11706            2  Mortaza enjoys moment to remember Bangladesh f...
# 11707            1  EU agrees to membership talks with Turkey HAMI...
# 11708            1  Bosnia Serb PM Resigns, Rejects Western Pressu...
# 11709            1  North Korea says US steps up espionage flights...
# 11710            3  Russia to hold Yukos auction despite US ruling...
# 11711            2  Utah Routs Pittsburgh in Fiesta Bowl  TEMPE, A...
# 11712            3  Stocks to Hold Up, But Anxiety Over Drugs  NEW...
# 11713            3  Despite Mega-Deals, Small Mergers Rule  Philad...
# 11714            3  Wal-Mart Dec. Sales Still Seen Up 1-3 Pct  CHI...
# 11715            3  Sabotage Stops Iraq's North Oil Exports  BAGHD...
# 11716            3  Corporate Cost-Cutters Miss Out  CHICAGO (Reut...
# 11717            3  Murdoch will shell out \$44 mil. for Manhattan...
# 11718            1  AU Says Sudan Begins Troop Withdrawal from Dar...
# 11719            1  Insurgents Attack Iraq Election Offices (Reute...
# 11720            1  Syria Redeploys Some Security Forces in Lebano...
# 11721            1  Security Scare Closes British Airport (AP) AP ...
# 11722            1  Iraqi Judges Start Quizzing Saddam Aides (AP) ...
# 11723            1  Musharraf says won't quit as army chief (Reute...
# 11724            1  Navy to go on PR 'offensive' to repair battere...
# 11725            2  NBA Wrap: Wade, O'Neal Carry Heat to 7th Strai...
# 11726            1  Barack Obama Gets  #36;1.9 Million Book Deal (...
# 11727            2  Rauffer Beats Favorites to Win Downhill  VAL G...
# 11728            1  Iraqis Face Winter Shivering by Candlelight  B...
# 11729            1  AU Says Sudan Begins Troop Withdrawal from Dar...
# 11730            1  Syria Redeploys Some Security Forces in Lebano...
# 11731            1  Pakistan's Musharraf Says Won't Quit as Army C...
# 11732            2  Renteria signing a top-shelf deal Red Sox gene...
# 11733            2  Saban not going to Dolphins yet The Miami Dolp...
# 11734            2  Today's NFL games PITTSBURGH at NY GIANTS Time...
# 11735            2  Nets get Carter from Raptors INDIANAPOLIS -- A...
#
#        category
# 0             3
# 1             3
# 2             3
# 3             3
# 4             3
# 5             3
# 6             3
# 7             3
# 8             3
# 9             3
# 10            3
# 11            3
# 12            3
# 13            3
# 14            3
# 15            3
# 16            3
# 17            3
# 18            3
# 19            3
# 20            3
# 21            3
# 22            3
# 23            3
# 24            3
# 25            3
# 26            3
# 27            3
# 28            3
# 29            3
# ...         ...
# 11706         2
# 11707         1
# 11708         1
# 11709         1
# 11710         3
# 11711         2
# 11712         3
# 11713         3
# 11714         3
# 11715         3
# 11716         3
# 11717         3
# 11718         1
# 11719         1
# 11720         1
# 11721         1
# 11722         1
# 11723         1
# 11724         1
# 11725         2
# 11726         1
# 11727         2
# 11728         1
# 11729         1
# 11730         1
# 11731         1
# 11732         2
# 11733         2
# 11734         2
# 11735         2
#
# [120000 rows x 3 columns]

# %% [markdown]
# # 观察每个类别的占比:

# %%
print(df["category"].value_counts())
# Out:
# 4    30000
# 3    30000
# 2    30000
# 1    30000
# Name: category, dtype: int64

# %% [markdown]
# # 丢弃有空值的列:

# %%
df=df.dropna(axis=0)

# %% [markdown]
# # 获得标签

# %%
num_classes = len(df["category"].unique())

# %% [markdown]
# # 分词：

# %%
import jieba
sentence=[[j.lower() for j in i.split(" ")] for i in df["content"]]

# %%
print (sentence[0])
# Out:
# ['wall', 'st.', 'bears', 'claw', 'back', 'into', 'the', 'black', '(reuters)', 'reuters', '-', 'short-sellers,', 'wall', "street's", 'dwindling\\band', 'of', 'ultra-cynics,', 'are', 'seeing', 'green', 'again.']

# %% [markdown]
# # 训练w2v词向量  size为词向量长度，迭代次数为10

# %%
import pandas as pd
import gensim
w2v_model = gensim.models.Word2Vec(sentence, size=128, iter=10, min_count=0)
word_vectors = w2v_model.wv
w2v_model.save("w2v")
w2v_model=gensim.models.Word2Vec.load("w2v")
# Out:
# /usr/local/lib/python3.5/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
w2v_model["wall"]

# %% [markdown]
# # 导入实现神经网络必要的包

# %%
from keras.layers import *
import numpy as np
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.merge import concatenate
from keras.layers.embeddings import Embedding
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras import backend as K
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from sklearn.model_selection import StratifiedKFold
from keras.utils.np_utils import to_categorical
from sklearn.metrics import f1_score, classification_report
from sklearn.model_selection import train_test_split
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 将文本转化成向量,将标签onehot,对文本向量以最大长度补零

# %%
x_train=sentence
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train)  #统计每个词对应的数字，以便于将文本转化成向量
train_sequence = tokenizer.texts_to_sequences(x_train)#将所有的文本转化成向量
MAX_SEQUENCE_LENGTH=128 #最大长度
EMBEDDING_DIM = 128 #向量维度
y_train =df["category"]
y_train = to_categorical(y_train)  #将标签 one-hot
y_train = y_train.astype(np.int32)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
train_pad = pad_sequences(train_sequence, maxlen=MAX_SEQUENCE_LENGTH) #将每条文本按照最大长度补0
# Out:
# Found 158716 unique tokens.

# %% [markdown]
# # 统计每个单词应该对应哪一条向量

# %%
embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM), dtype=np.float32)
not_in_model = 0
in_model = 0
embedding_max_value = 0
embedding_min_value = 1
not_words = []

for word, i in word_index.items():
    if word in w2v_model:
        in_model += 1
        embedding_matrix[i] = np.array(w2v_model[word])
        embedding_max_value = max(np.max(embedding_matrix[i]), embedding_max_value)
        embedding_min_value = min(np.min(embedding_matrix[i]), embedding_min_value)
    else:
        not_in_model += 1
        not_words.append(word)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if __name__ == '__main__':
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# # 用keras定义一个词嵌入层，并把刚才的矩阵加进去

# %%
embed = Embedding(len(word_index) + 1, EMBEDDING_DIM, weights=[embedding_matrix], input_length=MAX_SEQUENCE_LENGTH,
				  trainable=True)  #定义一个词嵌入层,将句子转化成对应的向量

# %% [markdown]
# # 划分验证集

# %%
# train_data, val_data, train_y, val_y = train_test_split(train_pad, y_train, test_size=0.2, random_state=43)
train_data=train_pad[:-df_val_num]
train_y=y_train[:-df_val_num]
val_data=train_pad[-df_val_num:]
val_y=y_train[-df_val_num:]

# %% [markdown]
# # 定义textcnn模型

# %%
def get_cnnmodel(embedding, class_num=5):
    inputs_sentence = Input(shape=(MAX_SEQUENCE_LENGTH,))#设置输入向量维度
    sentence =(embedding(inputs_sentence))#定义词嵌入层
    con=Conv1D(256, 5, padding='same')(sentence)
    maxp=MaxPooling1D(3, 3, padding='same')(con)
    con=Conv1D(128, 5, padding='same')(maxp)
    maxp=MaxPooling1D(3, 3, padding='same')(con)
    con=Conv1D(64, 3, padding='same')(maxp)
    fla=Flatten()(con)
    drop=Dropout(0.1)(fla)
    bn=BatchNormalization()(drop)
    ds=Dense(256, activation='relu')(bn)
    dp=Dropout(0.1)(ds)
    output = Dense(class_num, activation='softmax')(dp)#softmax层
    model = Model(inputs=[inputs_sentence], outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])#定义损失函数，优化器，评分标准
    model.summary()
    return model
# model = get_cnnmodel(embed)

# %% [markdown]
# # 开始训练

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
model = get_cnnmodel(embed)
callbacks = [EarlyStopping(monitor='val_acc', min_delta=0.001, patience=10),
			 ModelCheckpoint("textcnn.hdf5", monitor='val_acc',
							 mode='max', verbose=0, save_best_only=True)]   
#设置模型提前停止,停止的条件是验证集val_acc两轮已经不增加,保存验证集val_acc最大的那个模型,名称为new_cnn.hdf5
history=model.fit(train_data,train_y, batch_size=16, epochs=5, callbacks=callbacks,validation_data=(val_data,val_y))
#每次训练批次大小为64,遍历整整10次训练集才完成
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 128, 128)          20315776
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 128, 256)          164096
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 43, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 43, 128)           163968
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 15, 128)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 15, 64)            24640
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 960)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 960)               3840
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               246016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 20,919,621
# Trainable params: 20,917,701
# Non-trainable params: 1,920
# _________________________________________________________________
# Train on 108264 samples, validate on 11736 samples
# Epoch 1/5
# 108264/108264 [==============================] - 102s 945us/step - loss: 0.4105 - acc: 0.8615 - val_loss: 0.2995 - val_acc: 0.8991
# Epoch 2/5
# 108264/108264 [==============================] - 98s 909us/step - loss: 0.2786 - acc: 0.9072 - val_loss: 0.2715 - val_acc: 0.9062
# Epoch 3/5
# 108264/108264 [==============================] - 99s 911us/step - loss: 0.2133 - acc: 0.9297 - val_loss: 0.2601 - val_acc: 0.9142
# Epoch 4/5
# 108264/108264 [==============================] - 98s 909us/step - loss: 0.1659 - acc: 0.9458 - val_loss: 0.3044 - val_acc: 0.8976
# Epoch 5/5
# 108264/108264 [==============================] - 99s 911us/step - loss: 0.1285 - acc: 0.9576 - val_loss: 0.3303 - val_acc: 0.8993

# %% [markdown]
# # 加载最优的模型并且测试验证集

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
test_data=val_data
test_y=val_y
lstm_attention= load_model("textcnn.hdf5")
testpre=lstm_attention.predict([test_data])
tpre=np.argmax(testpre,axis=1)
testy=np.argmax(test_y,axis=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
from sklearn.metrics import classification_report
print (classification_report(testy,tpre,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            1     0.9287    0.8965    0.9123      2802
#            2     0.9592    0.9866    0.9727      2980
#            3     0.9003    0.8701    0.8850      3103
#            4     0.8686    0.9039    0.8859      2851
#
#    micro avg     0.9142    0.9142    0.9142     11736
#    macro avg     0.9142    0.9143    0.9140     11736
# weighted avg     0.9143    0.9142    0.9140     11736

# %%
import matplotlib.pyplot as plt
val_loss = history.history['val_loss']
loss = history.history['loss']
epochs = range(1, len(loss ) + 1)
plt.title('Loss')
plt.plot(epochs, loss, 'red', label='Training loss')
plt.plot(epochs, val_loss, 'blue', label='Validation loss')
plt.legend()
plt.show()

plt.cla()
val_loss = history.history['val_acc']
loss = history.history['acc']
epochs = range(1, len(loss ) + 1)
 
plt.title('acc')
plt.plot(epochs, loss, 'red', label='Training acc')
plt.plot(epochs, val_loss, 'blue', label='Validation acc')
plt.legend()
plt.show()

# %% [markdown]
# # 打印混淆矩阵和各个类别的准确率

# %%
def 给测试集输出指标(val_data):
    testpre=lstm_attention.predict([test_data])
    ypre=np.argmax(testpre,axis=1)
    ytrue=np.argmax(test_y,axis=1)
    def leibie_acc(test_pre,y_test):
        test_pre=np.array(test_pre)
        y_test=np.array(y_test)
#         label2汉字=dict(zip(d_category_to_number.values(), d_category_to_number.keys()))

        print ("准确率:",sum((test_pre==y_test).astype(int))/len(y_test))
        for i in set(list(y_test)):

            tmp=(test_pre[np.where(y_test==i)]==y_test[np.where(y_test==i)]).astype(int)
            acc=sum(tmp)/len(tmp)
            print (i,"类别准确率为:",acc,"数量为：",len(tmp))
        return 


    import seaborn as sns
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt

    def 混洗矩阵(valp,valy):
        sns.set()
        np.set_printoptions(suppress=True)
        f,ax=plt.subplots()
        valp=np.array(valp)
        valy=np.array(valy)
        C2= confusion_matrix(valy , valp, labels=list(range(1,len(set(df["category"]))+1)))
        print(C2) #打印出来看看
        sns.heatmap(C2,annot=True,ax=ax,fmt='.20g') #画热力图

        ax.set_title('confusion matrix') #标题
        ax.set_xlabel('predict') #x轴
        ax.set_ylabel('true') #y轴

    def 评价指标(val_data,val_y):
    #     valpre=model_load.predict(val_data)
        leibie_acc(val_data,val_y)
        混洗矩阵(val_data,val_y)

    评价指标(ypre,ytrue)
给测试集输出指标(test_data)
# Out:
# 准确率: 0.9141956373551465
# 1 类别准确率为: 0.8965024982155603 数量为： 2802
# 2 类别准确率为: 0.9865771812080537 数量为： 2980
# 3 类别准确率为: 0.8701256848211408 数量为： 3103
# 4 类别准确率为: 0.9038933707471063 数量为： 2851
# [[2512   68  130   92]
#  [  22 2940   10    8]
#  [  83   30 2700  290]
#  [  88   27  159 2577]]

# %% [markdown]
# # LSTM+attention

# %%
def attention_3d_block(inputs):

    input_dim = int(inputs.shape[2])

    a = Permute((2, 1))(inputs)
    a = Reshape((input_dim, train_data.shape[1]))(a) # this line is not useful. It's just to know which dimension is what.
    a = Dense(train_data.shape[1], activation='softmax')(a)
    a_probs = Permute((2, 1), name='attention_vec')(a)
    output_attention_mul = Multiply()([inputs, a_probs])
    return output_attention_mul

def get_lstmmodel(embedding, class_num=len(set(df["category"]))):
    inputs_sentence = Input(shape=(MAX_SEQUENCE_LENGTH,))  #设置输入向量维度
    sentence =(embedding(inputs_sentence))  #定义词嵌入层
    context1 = Bidirectional(LSTM(64, return_sequences=True))(sentence)  # 双向lstm层,lstm神经元维度为64
    atten = attention_3d_block(context1) #给lstm1层加上注意力机制
    atten = Flatten()(atten)
    x = Dense(100, activation='relu')(atten)# 全连接层,全连接层神经元维度为100
#     x = Dense(100, activation='relu')(x)# 全连接层,全连接层神经元维度为100
    output = Dense(5, activation='softmax')(atten)  #softmax层
    model = Model(inputs=[inputs_sentence], outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) #定义损失函数，优化器，评分标准
    model.summary()
    return model

# %%
model = get_lstmmodel(embed)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 128)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 128, 128)     20315776    input_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 128, 128)     98816       embedding_1[5][0]
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 128, 128)     0           bidirectional_5[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 128, 128)     0           permute_5[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 128, 128)     16512       reshape_5[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 128, 128)     0           dense_15[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 128, 128)     0           bidirectional_5[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 16384)        0           multiply_5[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 5)            81925       flatten_6[0][0]
# ==================================================================================================
# Total params: 20,513,029
# Trainable params: 20,513,029
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
model = get_lstmmodel(embed)
callbacks = [EarlyStopping(monitor='val_acc', min_delta=0.001, patience=10),
			 ModelCheckpoint("LSTM.hdf5", monitor='val_acc',
							 mode='max', verbose=0, save_best_only=True)]   
#设置模型提前停止,停止的条件是验证集val_acc两轮已经不增加,保存验证集val_acc最大的那个模型,名称为new_cnn.hdf5
history=model.fit(train_data,train_y, batch_size=16, epochs=5, callbacks=callbacks,validation_data=(val_data,val_y))
#每次训练批次大小为64,遍历整整10次训练集才完成
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 128)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 128, 128)     20315776    input_8[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 128, 128)     98816       embedding_1[7][0]
# __________________________________________________________________________________________________
# permute_7 (Permute)             (None, 128, 128)     0           bidirectional_7[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 128, 128)     0           permute_7[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 128, 128)     16512       reshape_7[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 128, 128)     0           dense_21[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 128, 128)     0           bidirectional_7[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 16384)        0           multiply_7[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 5)            81925       flatten_8[0][0]
# ==================================================================================================
# Total params: 20,513,029
# Trainable params: 20,513,029
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 108264 samples, validate on 11736 samples
# Epoch 1/5
# 108264/108264 [==============================] - 3257s 30ms/step - loss: 0.1083 - acc: 0.9637 - val_loss: 0.3056 - val_acc: 0.9009
# Epoch 2/5
#   5632/108264 [>.............................] - ETA: 49:25 - loss: 0.0418 - acc: 0.9860
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-8405bdcd54ab> in <module>
#       6 							 mode='max', verbose=0, save_best_only=True)]
#       7 #设置模型提前停止,停止的条件是验证集val_acc两轮已经不增加,保存验证集val_acc最大的那个模型,名称为new_cnn.hdf5
# ----> 8 history=model.fit(train_data,train_y, batch_size=16, epochs=5, callbacks=callbacks,validation_data=(val_data,val_y))
#       9 #每次训练批次大小为64,遍历整整10次训练集才完成
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
lstm_attention= load_model("LSTM.hdf5")
testpre=lstm_attention.predict([test_data])

# pre=[]
tpre=np.argmax(testpre,axis=1)
testy=np.argmax(test_y,axis=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
from sklearn.metrics import classification_report
print (classification_report(testy,tpre,digits=4))
import matplotlib.pyplot as plt
val_loss = history.history['val_loss']
loss = history.history['loss']
epochs = range(1, len(loss ) + 1)
plt.title('Loss')
plt.plot(epochs, loss, 'red', label='Training loss')
plt.plot(epochs, val_loss, 'blue', label='Validation loss')
plt.legend()
plt.show()

plt.cla()
val_loss = history.history['val_acc']
loss = history.history['acc']
epochs = range(1, len(loss ) + 1)
 
plt.title('acc')
plt.plot(epochs, loss, 'red', label='Training acc')
plt.plot(epochs, val_loss, 'blue', label='Validation acc')
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1     0.9315    0.8887    0.9096      2802
#            2     0.9715    0.9711    0.9713      2980
#            3     0.8966    0.8295    0.8617      3103
#            4     0.8139    0.9172    0.8625      2851
#
#    micro avg     0.9009    0.9009    0.9009     11736
#    macro avg     0.9034    0.9016    0.9013     11736
# weighted avg     0.9038    0.9009    0.9012     11736

# %%
def 给测试集输出指标(val_data):
    testpre=lstm_attention.predict([test_data])
    ypre=np.argmax(testpre,axis=1)
    ytrue=np.argmax(test_y,axis=1)
    def leibie_acc(test_pre,y_test):
        test_pre=np.array(test_pre)
        y_test=np.array(y_test)
#         label2汉字=dict(zip(d_category_to_number.values(), d_category_to_number.keys()))

        print ("准确率:",sum((test_pre==y_test).astype(int))/len(y_test))
        for i in set(list(y_test)):

            tmp=(test_pre[np.where(y_test==i)]==y_test[np.where(y_test==i)]).astype(int)
            acc=sum(tmp)/len(tmp)
            print (i,"类别准确率为:",acc,"数量为：",len(tmp))
        return 


    import seaborn as sns
    from sklearn.metrics import confusion_matrix
    import matplotlib.pyplot as plt

    def 混洗矩阵(valp,valy):
        sns.set()
        np.set_printoptions(suppress=True)
        f,ax=plt.subplots()
        valp=np.array(valp)
        valy=np.array(valy)
        C2= confusion_matrix(valy , valp, labels=list(range(1,len(set(df["category"]))+1)))
        print(C2) #打印出来看看
        sns.heatmap(C2,annot=True,ax=ax,fmt='.20g') #画热力图

        ax.set_title('confusion matrix') #标题
        ax.set_xlabel('predict') #x轴
        ax.set_ylabel('true') #y轴

    def 评价指标(val_data,val_y):
    #     valpre=model_load.predict(val_data)
        leibie_acc(val_data,val_y)
        混洗矩阵(val_data,val_y)

    评价指标(ypre,ytrue)
给测试集输出指标(test_data)
# Out:
# 准确率: 0.9009032038173143
# 1 类别准确率为: 0.8886509635974305 数量为： 2802
# 2 类别准确率为: 0.9711409395973154 数量为： 2980
# 3 类别准确率为: 0.8295198195294876 数量为： 3103
# 4 类别准确率为: 0.9172220273588214 数量为： 2851
# [[2490   49  112  151]
#  [  31 2894   26   29]
#  [  89   22 2574  418]
#  [  63   14  159 2615]]

# %%
# import jieba
cnn_model= load_model("textcnn.hdf5")
def getleibie(text):
#     d=dict(zip(d_category_to_number.values(),d_category_to_number.keys()))
#     print ([i for i in list(jieba.cut(text)) if i!=" "])
    x=tokenizer.texts_to_sequences([[i.lower() for i in text.split(" ")]])
    pre_X = pad_sequences(x, maxlen=MAX_SEQUENCE_LENGTH) #将每条文本按照最大长度补0
    return np.argmax(cnn_model.predict(pre_X),axis=-1)[0]
getleibie("i love you too")
# Out:
# 1

# %%
df_test=pd.read_csv("test.csv")

# %%
from tqdm import tqdm
tmppre=[]
for i,row in tqdm(df_test.iterrows()):
    tmppre.append(getleibie(row["Title"]+" "+row["Description"]))
# Out:
# 7600it [00:25, 302.33it/s]

# %%
df_test
# Out:
#       Class Index                                              Title  \
# 0               1                  Fears for T N pension after talks
# 1               1  The Race is On: Second Private Team Sets Launc...
# 2               1      Ky. Company Wins Grant to Study Peptides (AP)
# 3               1      Prediction Unit Helps Forecast Wildfires (AP)
# 4               1        Calif. Aims to Limit Farm-Related Smog (AP)
# 5               1  Open Letter Against British Copyright Indoctri...
# 6               1                       Loosing the War on Terrorism
# 7               1  FOAFKey: FOAF, PGP, Key Distribution, and Bloo...
# 8               1                   E-mail scam targets police chief
# 9               1                  Card fraud unit nets 36,000 cards
# 10              1    Group to Propose New High-Speed Wireless Format
# 11              1     Apple Launches Graphics Software, Video Bundle
# 12              1  Dutch Retailer Beats Apple to Local Download M...
# 13              1                    Super ant colony hits Australia
# 14              1                    Socialites unite dolphin groups
# 15              1                    Teenage T. rex's monster growth
# 16              1  Scientists Discover Ganymede has a Lumpy Interior
# 17              1      Mars Rovers Relay Images Through Mars Express
# 18              1                         Rocking the Cradle of Life
# 19              1                Storage, servers bruise HP earnings
# 20              1                  IBM to hire even more new workers
# 21              1               Sun's Looking Glass Provides 3D View
# 22              1              IBM Chips May Someday Heal Themselves
# 23              1   Some People Not Eligible to Get in on Google IPO
# 24              1        Rivals Try to Turn Tables on Charles Schwab
# 25              1  News: Sluggish movement on power grid cyber se...
# 26              1           Giddy Phelps Touches Gold for First Time
# 27              1              Tougher rules won't soften Law's game
# 28              1  Shoppach doesn't appear ready to hit the next ...
# 29              1          Mighty Ortiz makes sure Sox can rest easy
# ...           ...                                                ...
# 7570            1   AU Issues Deadline to Khartoum and Darfur Rebels
# 7571            1                               Skier Tests Positive
# 7572            1  Wenger vows no repeat of frailties against Bayern
# 7573            1          Microsoft buy comes with strings attached
# 7574            1   U.S. Army aims to halt paperwork with IBM system
# 7575            1                      Barcelona return for Mourinho
# 7576            1                 2005 American Bowl teams announced
# 7577            1              Carter could prove real plus for Nets
# 7578            1  Sudan govt unleashes offensive in South Darfur...
# 7579            1   Airbus chief wins fight to take controls at Eads
# 7580            1          England labour but find their second wind
# 7581            1  EBay #39;s Buy Of Rent.com May Lack Strategic ...
# 7582            1  Analysis: PeopleSoft users speak out about Ora...
# 7583            1                    Right-hander must pass physical
# 7584            1                              Pacers 89, Raptors 86
# 7585            1    Pricey Drug Trials Turn Up Few New Blockbusters
# 7586            1                 NBA Game Summary - Denver at Miami
# 7587            1           Hobbit-finding Boffins in science top 10
# 7588            1       Search providers seek video, find challenges
# 7589            1  The Newest Hope ; Marriage of Necessity Just M...
# 7590            1                               Saban hiring on hold
# 7591            1  Bosnian-Serb prime minister resigns in protest...
# 7592            1                   Historic Turkey-EU deal welcomed
# 7593            1    Mortaza strikes to lead superb Bangladesh rally
# 7594            1               Powell pushes diplomacy for N. Korea
# 7595            1                                   Around the world
# 7596            1                        Void is filled with Clement
# 7597            1                             Martinez leaves bitter
# 7598            1  5 of arthritis patients in Singapore take Bext...
# 7599            1                             EBay gets into rentals
#
#                                             Description
# 0     Unions representing workers at Turner   Newall...
# 1     SPACE.com - TORONTO, Canada -- A second\team o...
# 2     AP - A company founded by a chemistry research...
# 3     AP - It's barely dawn when Mike Fitzpatrick st...
# 4     AP - Southern California's smog-fighting agenc...
# 5     The British Department for Education and Skill...
# 6     \\"Sven Jaschan, self-confessed author of the ...
# 7     \\FOAF/LOAF  and bloom filters have a lot of i...
# 8     Wiltshire Police warns about "phishing" after ...
# 9     In its first two years, the UK's dedicated car...
# 10     LOS ANGELES (Reuters) - A group of technology...
# 11     LOS ANGELES (Reuters) - Apple Computer Inc.&l...
# 12     AMSTERDAM (Reuters) - Free Record Shop, a Dut...
# 13    A giant 100km colony of ants  which has been d...
# 14    Dolphin groups, or "pods", rely on socialites ...
# 15    Tyrannosaurus rex achieved its massive size du...
# 16    Jet Propulsion Lab -- Scientists have discover...
# 17    European Space Agency -- ESAs Mars Express has...
# 18    When did life begin? One evidential clue stems...
# 19    update Earnings per share rise compared with a...
# 20    By the end of the year, the computing giant pl...
# 21    Developers get early code for new operating sy...
# 22    New technology applies electrical fuses to hel...
# 23    Google has billed its IPO as a way for everyda...
# 24    By MICHAEL LIEDTKE     SAN FRANCISCO (AP) -- W...
# 25    Industry cyber security standards fail to reac...
# 26    Michael Phelps won the gold medal in the 400 i...
# 27    FOXBOROUGH -- Looking at his ridiculously deve...
# 28    With the weeks dwindling until Jason Varitek e...
# 29    Just imagine what David Ortiz could do on a go...
# ...                                                 ...
# 7570   ABUJA (Reuters) - The African Union issued a ...
# 7571  Olympic silver medalist Hans Knauss tests posi...
# 7572  ARSNE WENGER was raised in Alsace, near the Ge...
# 7573  A software company that Microsoft acquired thi...
# 7574  The U.S. Army has struck a deal with IBM and o...
# 7575  Jose Mourinho, the Chelsea manager, last night...
# 7576  New York, NY (Sports Network) - Indianapolis w...
# 7577  The Nets reported deal for Vince Carter very m...
# 7578  CAIRO, Dec 17 (AFP) -- One of the two main reb...
# 7579  The head of plane maker Airbus yesterday won a...
# 7580  This was not an easy day on which to play cric...
# 7581  Standard  amp; Poor #39;s Equity Research said...
# 7582  InfoWorld - The great debate over the impact o...
# 7583  Right-hander Matt Clement and the Boston Red S...
# 7584  Jamaal Tinsley scored 17 of his 22 points in t...
# 7585  The \$500 billion drug industry is stumbling b...
# 7586  Miami, FL (Sports Network) - Shaquille O #39;N...
# 7587  AP - Australian scientists who helped discover...
# 7588  Internet search providers are reacting to user...
# 7589  NEW YORK - The TV lights were on, the cameras ...
# 7590  DAVIE - The Dolphins want Nick Saban, and the ...
# 7591  Canadian Press - BANJA LUKA, Bosnia-Herzegovin...
# 7592  The European Union's decision to hold entry ta...
# 7593  Paceman Mashrafe Mortaza claimed two prize sca...
# 7594  WASHINGTON -- Outgoing Secretary of State Coli...
# 7595  Ukrainian presidential candidate Viktor Yushch...
# 7596  With the supply of attractive pitching options...
# 7597  Like Roger Clemens did almost exactly eight ye...
# 7598  SINGAPORE : Doctors in the United States have ...
# 7599  EBay plans to buy the apartment and home renta...
#
# [7600 rows x 3 columns]

# %%
df_test["Class Index"]=tmppre

# %%
df_test.to_csv("submit.csv",header=True,index=False,encoding="utf-8-sig")
